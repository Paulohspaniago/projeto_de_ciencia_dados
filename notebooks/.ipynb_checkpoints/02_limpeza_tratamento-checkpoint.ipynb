# %% [markdown]
# # 02 - Limpeza e Tratamento
#
# Objetivo:
# - padronizar nomes de colunas
# - tratar nulos
# - remover duplicatas
# - ajustar tipos e chaves `estado + ano`

# %%
import pandas as pd

# carregar aqui a primeira base limpa para trabalho incremental
